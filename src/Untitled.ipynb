# %%
import geopandas as gpd
import matplotlib

# %%
df = gpd.read_file("~/Downloads/World_Seas_IHO_v3/World_Seas_IHO_v3.shp")
df
# Out:
#                        NAME   ID   Longitude   Latitude       min_X  \
# 0           Rio de La Plata   33  -56.842478 -35.113338  -59.765656
# 1               Bass Strait  62A  146.424291 -39.450520  143.532508
# 2    Great Australian Bight   62  132.716558 -36.725916  117.614198
# 3                Tasman Sea   63  160.710798 -39.701056  146.872615
# 4        Mozambique Channel  45A   40.877244 -19.304095   32.430623
# ..                      ...  ...         ...        ...         ...
# 96            Laccadive Sea   42   75.182351   6.933697   71.982420
# 97                Skagerrak    3    9.641915  58.139755    6.998221
# 98            Norwegian Sea    6    4.566511  68.215650  -13.500655
# 99             Ligurian Sea  28d    8.913947  43.722295    7.538996
# 100          Gulf of Guinea   34    3.050898   3.254695   -7.726336
#
#          min_Y       max_X      max_Y     area  MRGID  \
# 0   -36.358856  -54.943024 -31.523437    31797   4325
# ...

# %%
df.plot()
# Out:
# <Axes: >
